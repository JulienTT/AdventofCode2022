# %%
#FOR PART I
import sys
import numpy as np
from functools import lru_cache,wraps
import collections as col
import string as st
import re
import time
import copy 

sys.setrecursionlimit(15000) 

def Read_file(file_name):
    with open(file_name) as input_file:
        list_of_lines=input_file.read().splitlines()
    Monkeys={}
    for line in list_of_lines:
        name=line.split(': ')[0]
        operations=line.split(': ')[1]
        Monkeys[name]=operations.split(' ')
    return Monkeys
    
def Score(monkey):
    global MyNumber
    if monkey=='humn':
        return MyNumber
    elif monkey=='root':
        return Score(Monkeys['root'][0])!=Score(Monkeys['root'][2])
    elif len(Monkeys[monkey])==1:
        return int(

# %%
#FOR PART I
import sys
import numpy as np
from functools import lru_cache,wraps
import collections as col
import string as st
import re
import time
import copy 

import matplotlib
from pylab import *
from matplotlib import pyplot as plt


sys.setrecursionlimit(15000) 

def Read_file(file_name):
    with open(file_name) as input_file:
        list_of_lines=input_file.read().splitlines()
    Monkeys={}
    for line in list_of_lines:
        name=line.split(': ')[0]
        operations=line.split(': ')[1]
        Monkeys[name]=operations.split(' ')
    return Monkeys
    
def Score(monkey):
    global MyNumber
    if monkey=='humn':
        return 'humn'
    elif monkey=='root':
        return Score(Monkeys['root'][0])+'-'+Score(Monkeys['root'][2])
    elif len(Monkeys[monkey])==1:
        return Monkeys[monkey][0]
    else:
        score1=Score(Monkeys[monkey][0])
        score2=Score(Monkeys[monkey][2])
        
        if 'humn' not in score1:
                score1=str(eval(score1))
        if 'humn' not in score2:
                score2=str(eval(score2))
        if 'humn' not in score1 and 'humn' not in score2:
            return str(eval(str(score1)+str(Monkeys[monkey][1])+str(score2)))
        else:
            return '('+str(score1)+')'+str(Monkeys[monkey][1])+'('+str(score2)+')'
        
    
if __name__ == '__main__':
    
    Monkeys=Read_file('example')
    X1=0
    X2=1000
    Monkeys=Read_file('input')
    X1=1*10**12
    X2=5500000000000+1000#10*10**12

    Monkeys['root'][1]='=='
    start_time = time.time()
    MyNumber=301
    Operation=Score('root')
    print(Operation)
    Xtest=int((X1+X2)/2)
    Result=eval(Operation.replace('humn',str(Xtest)))
    print(Test)
    X=range(X1,X2,int((X2-X1)/1000))
    Func=[eval(Operation.replace('humn',str(x))) for x in X]
    #     print(eval(Operation.replace('numb',str(MyNumber))))
    plt.plot(X,Func)
    plt.show()
    
    while Result!=0:
        if(Result>0):
            X1=Xtest
        else:
            X2=Xtest
        Xtest=int((X1+X2)/2)
        print(Xtest)
        Result=eval(Operation.replace('humn',str(Xtest)))

    
    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# (9)*((((193764052094285.0)-(((226)+((2)*((((((881.0)+((((216)+(((2)*(((((516)+(((((2)*((((((((285)+(((190)+(((2)*((122.0)+((((((9)*((((917)+((7)*((((114)+((317.0)+((2)*(((((6)*((((((((((10)*((((765)+((18)*((((humn)-(334.0))/(3))+(574))))/(3))-(899.0)))+(589))*(2))-(472.0))/(3))-(733))+(820))/(3))+(77)))-(476))/(4))+(396)))))/(5))-(297))))/(7))-(583)))-(726))*(2))+(320.0))/(2))))-(115)))/(3)))/(2))-(910))*(4))+(754))/(2))-(545.0)))+(580.0))*(2))-(729)))+(25))/(3))+(549.0)))-(273)))+(685.0))/(2)))/(3))-(972.0))*(4))-(598.0))))/(2)))/(9))+(937))-88521161883075.0
# 500.0
# 4375000000750
# 3812500000625
# 3531250000562
# 3671875000593
# 3742187500609
# 3707031250601
# 3689453125597
# 3698242188099
# 3702636719350
# 3700439453724
# 3699340820911
# 3699890137317
# 3700164795520
# 3700027466418
# 3699958801867
# 3699924469592
# 3699941635729
# 3699950218798
# 3699945927263
# 3699943781496
# 3699944854379
# 3699945390821
# 3699945122600
# 3699945256710
# 3699945323765
# 3699945357293
# ...
