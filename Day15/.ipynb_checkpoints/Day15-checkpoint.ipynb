# %%
import sys
import numpy as np
from functools import lru_cache,wraps
import collections as col
import string as st
import re

sys.setrecursionlimit(15000) 

def Read_file(file_name):
    Beacons=[]
    with open(file_name) as input_file:
        list_of_lines=input_file.read().splitlines()
    for line in list_of_lines:
        line=line.replace('Sensor at x=','')
        line=line.replace(' y=','')
        line=line.replace(': closest beacon is at x=',',')
        line=line.replace(' ','')
        Beacons.append([int(i) for i in line.split(',')])
    return Beacons

if __name__ == '__main__':
    Beacons=Read_file('example')
    #Beacons=Read_file('input')
    print(Beacons)
    #yt=2000000
    yt=10
    Nothing=set()
    for Beacon in Beacons:
        #print(Beacon)
        d=abs(Beacon[0]-Beacon[2])+abs(Beacon[1]-Beacon[3])
        #print('distance',d)
        d1=d-abs(Beacon[1]-yt)
        if (d1>=0):
            for x in range(Beacon[0]-d1,Beacon[0]+d1+1):
                Nothing.add(x)
    for Beacon in Beacons:
        if (Beacon[3]==yt):
            Nothing.discard(Beacon[2])
    print(Nothing)
    print(len(Nothing))

# %%
import sys
import numpy as np
from functools import lru_cache,wraps
import collections as col
import string as st
import re
import time


def Read_file(file_name):
    Beacons=[]
    with open(file_name) as input_file:
        list_of_lines=input_file.read().splitlines()
    for line in list_of_lines:
        line=line.replace('Sensor at x=','')
        line=line.replace(' y=','')
        line=line.replace(': closest beacon is at x=',',')
        line=line.replace(' ','')
        Beacons.append([int(i) for i in line.split(',')])
    return Beacons
        
if __name__ == '__main__':

    Beacons=Read_file('example')
    #Beacons=Read_file('input')
    print(Beacons)
    #yt=2000000
    yt=10
    Xmin=0
    Xmax=20
    Ymin=0
    Ymax=20
    start_time = time.time()
    Nothing=set()
    for Beacon in Beacons:
        #print(Beacon)
        d=abs(Beacon[0]-Beacon[2])+abs(Beacon[1]-Beacon[3])
        #print('distance',d)
        d1=d-abs(Beacon[1]-yt)
        if (d1>=0):
            Nothing.add((Beacon[0]-d1,Beacon[0]+d1))   
    print(Nothing)
    (xmin,xmax)=list(Nothing)[0]
    print(xmin,xmax)
    for Inter in Nothing:
        (x1,x2)=Inter
        xmin=min(x1,xmin)
        xmax=max(x2,xmax)
    print(xmin,xmax)
    X=np.zeros(xmax-xmin+1)
    for Inter in Nothing:
        for x in range(Inter[0],Inter[1]+1):
            X[x-xmin]=1;
    for Beacon in Beacons:
        if (Beacon[3]==yt):
            X[Beacon[2]-xmin]=0
    print(sum(X))
    print("--- %s seconds ---" % (time.time() - start_time))
    sys.setrecursionlimit(15000)

# %%
import sys
import numpy as np
from functools import lru_cache,wraps
import collections as col
import string as st
import re
import time


def Read_file(file_name):
    Beacons=[]
    with open(file_name) as input_file:
        list_of_lines=input_file.read().splitlines()
    for line in list_of_lines:
        line=line.replace('Sensor at x=','')
        line=line.replace(' y=','')
        line=line.replace(': closest beacon is at x=',',')
        line=line.replace(' ','')
        Beacons.append([int(i) for i in line.split(',')])
    return Beacons
        
def Remove(i1,i2,j1,j2):
    
    
    
if __name__ == '__main__':

    #Beacons=Read_file('example')
    Beacons=Read_file('input')
    print(Beacons)
    yt=2000000
    #yt=10
    Xmin=0
    Xmax=20
    Ymin=0
    Ymax=20
    start_time = time.time()
    Nothing=[]
    for Beacon in Beacons:
        #print(Beacon)
        d=abs(Beacon[0]-Beacon[2])+abs(Beacon[1]-Beacon[3])
        #print('distance',d)
        d1=d-abs(Beacon[1]-yt)
        if (d1>=0):
            Nothing.append([Beacon[0]-d1,Beacon[0]+d1])   
    print(Nothing)
    #Remove interval from all successive intervals
    for i in range(len(Nothing)):
        if(len(Nothing[i])>0):
            [i1,i2]=Nothing[i]
            for j in range(len(Nothing),i,-1):
                if(len(Nothing[j])>0):
                    if(i2>j1 and i1<j2):
                    [j1,j2]=Nothing[j]
                    Nothing[j]=Remove(i1,i2,j1,j2)
                
            
    
    [xmin,xmax]=Nothing[0]
    print(xmin,xmax)
    for Inter in Nothing:
        [x1,x2]=Inter
        xmin=min(x1,xmin)
        xmax=max(x2,xmax)
    print(xmin,xmax)
    X=np.zeros(xmax-xmin+1)
    for Inter in Nothing:
        for x in range(Inter[0],Inter[1]+1):
            X[x-xmin]=1;
    for Beacon in Beacons:
        if (Beacon[3]==yt):
            X[Beacon[2]-xmin]=0
    print(sum(X))
    print("--- %s seconds ---" % (time.time() - start_time))
    sys.setrecursionlimit(15000)

# %%
print(range(10,8))

# %%
for i in range(10,8,-1):
    print(i)
# Out:
# 10
# 9
